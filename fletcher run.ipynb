# %%
import os
import numpy as np
import easyvvuq as uq
import chaospy as cp
import matplotlib.pyplot as plt
from easyvvuq.actions import CreateRunDirectory, Encode, Decode, ExecuteLocal, Actions

# %% [markdown]
# ### Setting up an EasyVVUQ campaign
#
# We first set up the `params` dictionary, in which we specify the name, type and default value of each input:

# %%
# number of inputs
d = 3

# params dict
params = {}

params['BSIZE_X'] = {'type': 'integer', 'default': 256.0}  # block size parameter
params['BSIZE_Y'] = {'type': 'integer', 'default': 2.0}  # block size parameter
# params['BSIZE_Z'] = {'type': 'integer', 'default': 4.0}  # block size parameter

# params['CLK'] = {'type': 'integer', 'default': 1500.0}  # clock speed in MHz
params['POWER_CAP'] = {'type': 'integer', 'default': 220.0}  # power cap in watts

params
# Out:
# {'BSIZE_X': {'type': 'integer', 'default': 256.0},
#  'BSIZE_Y': {'type': 'integer', 'default': 2.0},
#  'POWER_CAP': {'type': 'integer', 'default': 220.0}}

# %%
# input file encoder
encoder = uq.encoders.GenericEncoder(template_fname='fletcher.template', delimiter='$', target_filename='input.csv')

# %% [markdown]
# The model writes a CSV file `output.csv` containing the prediction $f({\bf x})$. The **decoder** will read this file and store its contents within the EasyVVUQ database.

# %%
# Quantity of Interest, also the column name of the output CSV file
QOI = 'f'
# CSV output file decoder
decoder = uq.decoders.SimpleCSV(target_filename='output.csv', output_columns=[QOI])

# %% [markdown]
# We'll run the ensemble locally. However, in many cases of practical interest the model will be too expensive for local execution. In this case the VECMA tools [QCG-PilotJob](https://github.com/vecma-project/QCG-PilotJob) or [FabSim3](https://github.com/djgroen/FabSim3) can be used in combination with EasyVVUQ to submit the ensemble to HPC resources.

# %%
# local execution of HIV_model.py
execute = ExecuteLocal('{}/fletcher.py'.format(os.getcwd()))

# %% [markdown]
# Now we are combine all actions we want to execute into an `Actions` object.

# %%
# location where the run directories are stored
WORK_DIR = '/tmp'
# actions to be undertaken: make rundirs, encode input files, execute local model ensemble, decode output files
actions = Actions(CreateRunDirectory(root=WORK_DIR, flatten=True), Encode(encoder), execute, 
                  Decode(decoder))

# %% [markdown]
# The central object in the UQ analysis is a so-called Campaign. This is created as:

# %%
campaign = uq.Campaign(name='fletcher', params=params, actions=actions, work_dir=WORK_DIR)

# %% [markdown]
# We do redefine `vary`, as we will include all `D` inputs in the uncertainty analysis this time.

# %%
# vary = {}
# vary['BSIZE_X'] = cp.Uniform(1, 512)

# vary['BSIZE_X'].interpret_as_integer = True


# Define possible values (powers of 2)
powers_of_two = np.array([2**i for i in range(0, 10)])  # 1, 2, 4, ..., 512



# CHAOSPY 

vary = {}
vary['BSIZE_X'] = cp.Uniform(1, len(powers_of_two) - 1)
vary['BSIZE_X'].interpret_as_integer = True

vary['BSIZE_Y'] = cp.Uniform(1, len(powers_of_two) - 1)
vary['BSIZE_Y'].interpret_as_integer = True

# vary['CLK'] = cp.Uniform(500, 2700)  # Clock speed between 1000 MHz and 3000 MHz
# vary['CLK'].interpret_as_integer = True

vary['POWER_CAP'] = cp.Uniform(198, 220)  # Power cap between
vary['POWER_CAP'].interpret_as_integer = True

# %% [markdown]
# We now select the adaptive Stochastic Collocation sampler. Here
#
# * `polynomial_order = 1`: should be interpreted in the sparse context as starting the sampling plan with a level 1 quadrature rule for all inputs.
# * `quadrature_rule='C'`: selects the Clenshaw Curtis quadrature rule.
# * `sparse=True`: selects the sparse grid.
# * `growth=True`: selects an exponential growth rule which makes the Clenshaw Curtis rule nested.
# * `dimension_adaptive=True`: selects the dimension-adaptive sampler.

# %%
sampler = uq.sampling.SCSampler(vary=vary, polynomial_order=1, quadrature_rule='C', sparse=True,
                                growth=True, dimension_adaptive=True)
campaign.set_sampler(sampler)

# %% [markdown]
# Run the first ensemble, which consists of just a single sample:

# %%
campaign.execute(sequential=True, mark_invalid=True).collate(progress_bar=True)
# Out:
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_8
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=6.133908e+02; vpz=1.419724e+03, v2pz=2.015616e+06
# v2sz=3.762483e+05; v2pz=2.015616e+06, v2px=2.983112e+06, v2pn=2.418739e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.15036
# Total Time Dump = 0.12738
# Execution time (s) is 0.971901
# MSamples/s 1317
# Memory High Water Mark is 15890148 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.04634
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1317.254246
# 100%|██████████| 1/1 [00:00<00:00, 1210.48it/s]

# %% [markdown]
# To analyse the results (and execute the dimension adaptivity), we need an `SCAnalysis` object:

# %%
analysis = uq.analysis.SCAnalysis(sampler=sampler, qoi_cols=[QOI])
# perform analysis (basically estimates moments, Sobol analysis, and updates internal state of analysis)
campaign.apply_analysis(analysis)

# %% [markdown]
# Now we'll refine the grid several times in an anisotropic fashion. Here
#
# * `look_ahead`: determines the new admissible candidate refinements.
# * `campaign.get_collation_result()`: get the data frame with all code samples.
# * `adapt_dimension`: compute the hierarchical surplus at all candidate refinements, and accept the one with the highest surplus.

# %%
number_of_adaptations = 20
for i in range(number_of_adaptations):
    # compute candidate refinements
    sampler.look_ahead(analysis.l_norm)
    # run ensemble (at new locations only)
    campaign.execute(sequential=True, mark_invalid=True).collate(progress_bar=True)
    # get dataframe
    data_frame = campaign.get_collation_result()
    # adapt the sampling plan
    analysis.adapt_dimension(QOI, data_frame)
    # we must apply the analysis to update its internal state
    campaign.apply_analysis(analysis)
# Out:
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_9
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=6.733362e+02; vpz=1.558471e+03, v2pz=2.428830e+06
# v2sz=4.533817e+05; v2pz=2.428830e+06, v2px=3.594669e+06, v2pn=2.914596e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14905
# Total Time Dump = 0.12694
# Execution time (s) is 0.971144
# MSamples/s 1318
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.08356
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1318.281332
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 9, 5
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_11
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.200362e+02; vpz=7.407399e+02, v2pz=5.486956e+05
# v2sz=1.024232e+05; v2pz=5.486956e+05, v2px=8.120695e+05, v2pn=6.584348e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14579
# Total Time Dump = 0.12434
# Execution time (s) is 0.970471
# MSamples/s 1319
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.78859
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1319.195282
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=2, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_12
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=2.573947e+02; vpz=5.957531e+02, v2pz=3.549218e+05
# v2sz=6.625205e+04; v2pz=3.549218e+05, v2px=5.252842e+05, v2pn=4.259061e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.98637
# Total Time Dump = 0.12306
# Execution time (s) is 1.811472
# MSamples/s 707
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.61044
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 706.740531
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 9
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_14
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=2.220045e+02; vpz=5.138405e+02, v2pz=2.640320e+05
# v2sz=4.928598e+04; v2pz=2.640320e+05, v2px=3.907673e+05, v2pn=3.168384e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.22171
# Total Time Dump = 0.12599
# Execution time (s) is 1.043413
# MSamples/s 1227
# Memory High Water Mark is 15890148 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.09497
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1226.973546
# 100%|██████████| 6/6 [00:00<00:00, 2854.24it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=4
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_15
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.067946e+03; vpz=2.471815e+03, v2pz=6.109870e+06
# v2sz=1.140509e+06; v2pz=6.109870e+06, v2px=9.042608e+06, v2pn=7.331844e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20299
# Total Time Dump = 0.12452
# Execution time (s) is 1.025556
# MSamples/s 1248
# Memory High Water Mark is 15889792 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.98960
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1248.337715
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 8
# 100%|██████████| 2/2 [00:00<00:00, 1838.80it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 9, 9
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=2, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_18
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=6.089603e+02; vpz=1.409469e+03, v2pz=1.986604e+06
# v2sz=3.708327e+05; v2pz=1.986604e+06, v2px=2.940173e+06, v2pn=2.383924e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 3.38234
# Total Time Dump = 0.12505
# Execution time (s) is 3.206123
# MSamples/s 399
# Memory High Water Mark is 15890016 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 16.10261
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 399.311188
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=512, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_19
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=5.036158e+02; vpz=1.165644e+03, v2pz=1.358726e+06
# v2sz=2.536288e+05; v2pz=1.358726e+06, v2px=2.010914e+06, v2pn=1.630471e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14543
# Total Time Dump = 0.12559
# Execution time (s) is 0.967447
# MSamples/s 1323
# Memory High Water Mark is 15889908 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.05038
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1323.318899
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=2, BSIZE_Y=512
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_20
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=5.015945e+02; vpz=1.160966e+03, v2pz=1.347841e+06
# v2sz=2.515970e+05; v2pz=1.347841e+06, v2px=1.994805e+06, v2pn=1.617410e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 7.92839
# Total Time Dump = 0.12705
# Execution time (s) is 7.748363
# MSamples/s 165
# Memory High Water Mark is 15889960 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 21.01021
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 165.227246
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=4, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_21
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=5.585418e+02; vpz=1.292773e+03, v2pz=1.671262e+06
# v2sz=3.119689e+05; v2pz=1.671262e+06, v2px=2.473468e+06, v2pn=2.005515e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20451
# Total Time Dump = 0.12335
# Execution time (s) is 1.027951
# MSamples/s 1245
# Memory High Water Mark is 15890108 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.97085
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1245.429056
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 8, 5
# 100%|██████████| 6/6 [00:00<00:00, 2773.09it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 7
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=8
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_24
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.995544e+02; vpz=9.247888e+02, v2pz=8.552344e+05
# v2sz=1.596437e+05; v2pz=8.552344e+05, v2px=1.265747e+06, v2pn=1.026281e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.15686
# Total Time Dump = 0.12518
# Execution time (s) is 0.979390
# MSamples/s 1307
# Memory High Water Mark is 15890116 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.04396
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1307.181143
# 100%|██████████| 2/2 [00:00<00:00, 1649.35it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=2, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_25
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=8.991053e+02; vpz=2.081024e+03, v2pz=4.330662e+06
# v2sz=8.083904e+05; v2pz=4.330662e+06, v2px=6.409380e+06, v2pn=5.196795e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.99281
# Total Time Dump = 0.12526
# Execution time (s) is 1.814136
# MSamples/s 706
# Memory High Water Mark is 15890148 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.72161
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 705.702578
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 9
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_27
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=9.652211e+02; vpz=2.234053e+03, v2pz=4.990992e+06
# v2sz=9.316518e+05; v2pz=4.990992e+06, v2px=7.386668e+06, v2pn=5.989190e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14748
# Total Time Dump = 0.12431
# Execution time (s) is 0.970955
# MSamples/s 1319
# Memory High Water Mark is 15889892 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.90887
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1318.537706
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_28
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=4.115119e+02; vpz=9.524650e+02, v2pz=9.071895e+05
# v2sz=1.693420e+05; v2pz=9.071895e+05, v2px=1.342640e+06, v2pn=1.088627e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.21930
# Total Time Dump = 0.12253
# Execution time (s) is 1.043605
# MSamples/s 1227
# Memory High Water Mark is 15890028 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.85093
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1226.748737
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 9
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_30
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.828932e+02; vpz=8.862256e+02, v2pz=7.853958e+05
# v2sz=1.466072e+05; v2pz=7.853958e+05, v2px=1.162386e+06, v2pn=9.424750e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.15011
# Total Time Dump = 0.12944
# Execution time (s) is 0.970717
# MSamples/s 1319
# Memory High Water Mark is 15889944 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.13148
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1318.860906
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_31
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=5.724196e+02; vpz=1.324894e+03, v2pz=1.755344e+06
# v2sz=3.276642e+05; v2pz=1.755344e+06, v2px=2.597909e+06, v2pn=2.106413e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.22061
# Total Time Dump = 0.12341
# Execution time (s) is 1.043904
# MSamples/s 1226
# Memory High Water Mark is 15889628 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.91695
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1226.396552
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 9, 5
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 9, 5
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=2, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_34
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.551662e+02; vpz=3.591400e+02, v2pz=1.289815e+05
# v2sz=2.407656e+04; v2pz=1.289815e+05, v2px=1.908927e+05, v2pn=1.547779e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.98893
# Total Time Dump = 0.12429
# Execution time (s) is 1.813764
# MSamples/s 706
# Memory High Water Mark is 15890140 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.65008
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 705.847383
# 100%|██████████| 10/10 [00:00<00:00, 3234.60it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 219000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_35
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.125493e+02; vpz=2.605009e+02, v2pz=6.786074e+04
# v2sz=1.266734e+04; v2pz=6.786074e+04, v2px=1.004339e+05, v2pn=8.143289e+04
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14864
# Total Time Dump = 0.12606
# Execution time (s) is 0.971302
# MSamples/s 1318
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.02139
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1318.066792
# --PowerCap set--
# Return code: 0
# Stdout: 213000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_36
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=7.768351e+02; vpz=1.798024e+03, v2pz=3.232890e+06
# v2sz=6.034728e+05; v2pz=3.232890e+06, v2px=4.784678e+06, v2pn=3.879468e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14575
# Total Time Dump = 0.12515
# Execution time (s) is 0.971138
# MSamples/s 1318
# Memory High Water Mark is 15889892 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.77982
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1318.288776
# --PowerCap set--
# Return code: 0
# Stdout: 205000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_37
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.325800e+02; vpz=7.697733e+02, v2pz=5.925509e+05
# v2sz=1.106095e+05; v2pz=5.925509e+05, v2px=8.769753e+05, v2pn=7.110611e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14754
# Total Time Dump = 0.12304
# Execution time (s) is 0.972264
# MSamples/s 1317
# Memory High Water Mark is 15889640 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.76304
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1316.762614
# --PowerCap set--
# Return code: 0
# Stdout: 199000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_38
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.039172e+03; vpz=2.405216e+03, v2pz=5.785066e+06
# v2sz=1.079879e+06; v2pz=5.785066e+06, v2px=8.561897e+06, v2pn=6.942078e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14910
# Total Time Dump = 0.12510
# Execution time (s) is 0.970513
# MSamples/s 1319
# Memory High Water Mark is 15890148 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.00559
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1319.138245
# 100%|██████████| 4/4 [00:00<00:00, 2554.00it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 9
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 9
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=4
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_41
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=7.072593e+02; vpz=1.636987e+03, v2pz=2.679727e+06
# v2sz=5.002157e+05; v2pz=2.679727e+06, v2px=3.965996e+06, v2pn=3.215672e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20697
# Total Time Dump = 0.12435
# Execution time (s) is 1.029088
# MSamples/s 1244
# Memory High Water Mark is 15889964 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.94632
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1244.053584
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=4
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_42
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.443005e+02; vpz=3.339909e+02, v2pz=1.115499e+05
# v2sz=2.082264e+04; v2pz=1.115499e+05, v2px=1.650939e+05, v2pn=1.338599e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20585
# Total Time Dump = 0.12577
# Execution time (s) is 1.027462
# MSamples/s 1246
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.03857
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1246.021788
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_43
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.232373e+03; vpz=2.852389e+03, v2pz=8.136124e+06
# v2sz=1.518743e+06; v2pz=8.136124e+06, v2px=1.204146e+07, v2pn=9.763349e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.22085
# Total Time Dump = 0.12642
# Execution time (s) is 1.043059
# MSamples/s 1227
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.20979
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1227.390305
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 8
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=2
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_45
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=8.364188e+02; vpz=1.935933e+03, v2pz=3.747838e+06
# v2sz=6.995964e+05; v2pz=3.747838e+06, v2px=5.546801e+06, v2pn=4.497406e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.21977
# Total Time Dump = 0.12577
# Execution time (s) is 1.043926
# MSamples/s 1226
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.10574
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1226.370784
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 8
# 100%|██████████| 8/8 [00:00<00:00, 1887.63it/s]
# 0it [00:00, ?it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=4
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_47
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.871874e+02; vpz=4.332546e+02, v2pz=1.877096e+05
# v2sz=3.503911e+04; v2pz=1.877096e+05, v2px=2.778102e+05, v2pn=2.252515e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20256
# Total Time Dump = 0.12468
# Execution time (s) is 1.026649
# MSamples/s 1247
# Memory High Water Mark is 15890308 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.86943
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1247.009097
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 8
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=32, BSIZE_Y=4
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_49
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.873064e+02; vpz=8.964401e+02, v2pz=8.036048e+05
# v2sz=1.500062e+05; v2pz=8.036048e+05, v2px=1.189335e+06, v2pn=9.643258e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20477
# Total Time Dump = 0.12507
# Execution time (s) is 1.026856
# MSamples/s 1247
# Memory High Water Mark is 15890152 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.97232
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1246.757781
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 5, 8
# 100%|██████████| 4/4 [00:00<00:00, 2645.00it/s]
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=8, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_51
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.754476e+02; vpz=8.689924e+02, v2pz=7.551479e+05
# v2sz=1.409609e+05; v2pz=7.551479e+05, v2px=1.117619e+06, v2pn=9.061774e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.12916
# Total Time Dump = 0.12576
# Execution time (s) is 0.950027
# MSamples/s 1348
# Memory High Water Mark is 15890148 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.99805
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1347.584119
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 7, 5
# 100%|██████████| 2/2 [00:00<00:00, 1777.62it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 6, 5
# --PowerCap set--
# Return code: 0
# Stdout: 209000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=16, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_54
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.237784e+03; vpz=2.864913e+03, v2pz=8.207728e+06
# v2sz=1.532109e+06; v2pz=8.207728e+06, v2px=1.214744e+07, v2pn=9.849274e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14859
# Total Time Dump = 0.12505
# Execution time (s) is 0.972556
# MSamples/s 1316
# Memory High Water Mark is 15889440 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.88943
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1316.366862
# 100%|██████████| 2/2 [00:00<00:00, 2021.84it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# 0it [00:00, ?it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 0it [00:00, ?it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# ...
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 0it [00:00, ?it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=4, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_63
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=1.715482e+02; vpz=3.970569e+02, v2pz=1.576542e+05
# v2sz=2.942878e+04; v2pz=1.576542e+05, v2px=2.333282e+05, v2pn=1.891850e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20596
# Total Time Dump = 0.12574
# Execution time (s) is 1.027767
# MSamples/s 1246
# Memory High Water Mark is 15889916 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.04941
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1245.652095
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 8, 5
# --PowerCap set--
# Return code: 0
# Stdout: 217000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=4, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_65
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=6.913774e+02; vpz=1.600228e+03, v2pz=2.560728e+06
# v2sz=4.780027e+05; v2pz=2.560728e+06, v2px=3.789878e+06, v2pn=3.072874e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.20735
# Total Time Dump = 0.12612
# Execution time (s) is 1.028292
# MSamples/s 1245
# Memory High Water Mark is 15889896 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.08963
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1245.016701
# --PowerCap set--
# Return code: 0
# Stdout: 201000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 8, 5
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 7, 5
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=8, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_68
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=7.049736e+02; vpz=1.631697e+03, v2pz=2.662435e+06
# v2sz=4.969878e+05; v2pz=2.662435e+06, v2px=3.940404e+06, v2pn=3.194922e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.12499
# Total Time Dump = 0.12615
# Execution time (s) is 0.950096
# MSamples/s 1347
# Memory High Water Mark is 15890144 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.03117
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1347.485036
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=8, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_69
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=3.531248e+02; vpz=8.173252e+02, v2pz=6.680205e+05
# v2sz=1.246971e+05; v2pz=6.680205e+05, v2px=9.886703e+05, v2pn=8.016246e+05
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.12538
# Total Time Dump = 0.12346
# Execution time (s) is 0.949716
# MSamples/s 1348
# Memory High Water Mark is 15889348 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.85624
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1348.024585
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 7, 5
# 100%|██████████| 8/8 [00:00<00:00, 2845.53it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=16, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_71
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=7.946084e+02; vpz=1.839161e+03, v2pz=3.382514e+06
# v2sz=6.314025e+05; v2pz=3.382514e+06, v2px=5.006120e+06, v2pn=4.059017e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.14965
# Total Time Dump = 0.12366
# Execution time (s) is 0.972793
# MSamples/s 1316
# Memory High Water Mark is 15889772 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 13.96148
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1316.046174
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Running Fletcher with BSIZE_X=16, BSIZE_Y=32
# Current working directory: /tmp/fletcher8h0k_hfi/runs/run_72
# Return code: 0
# Stdout: Problem is anisotropic with tilted transversely isotropy using sigma=0.750000
# Grid size is (472,472,472) with spacing (12.50,12.50,12.50); simulated area (5887.50,5887.50,5887.50)
# Grid is extended by 16 absortion points and 4 border points at each extreme
# Wave is propagated at internal+absortion points of size (504,504,504)
# Total grid size: 512 x 512 x 512
# Source at coordinates (256,256,256)
# Will run 10 time steps of 0.001000 to reach time 0.010000
# Recomended maximum time step is 0.000685; used time step is 0.001000
# Slice of TTI.rsf at iteration; 00000; time(s); 0.000000; max;  0.00e+00; min;  0.00e+00; src;  0.00e+00;
# ch1dxx=0.145963; ch1dyy=0.354037; ch1dzz=0.500000; ch1dxy=0.454649; ch1dxz=0.540302; ch1dyz=0.841471
# vsv=6.717425e+02; vpz=1.554782e+03, v2pz=2.417346e+06
# v2sz=4.512380e+05; v2pz=2.417346e+06, v2px=3.577672e+06, v2pn=2.900816e+06
# HIP source using device(0) AMD Radeon RX 7700 XT with compute capability 11.0.
# GPU memory usage = 10240 MiB
# Slice of TTI.rsf at iteration; 00010; time(s); 0.010000; max;  7.79e-07; min; -5.11e-04; src; -3.14e-04;
# Total Time iters = 1.15053
# Total Time Dump = 0.12576
# Execution time (s) is 0.972646
# MSamples/s 1316
# Memory High Water Mark is 15889980 kB
# HIP_Finalize: SUCCESS
# Total Model Time = 14.05384
#
# Stderr:
# Report.csv found at Report.csv
# Extracted MSamples: 1316.245214
# --PowerCap set--
# Return code: 0
# Stdout: 220000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 6, 5
# --PowerCap set--
# Return code: 0
# Stdout: 198000000
# Stderr:
# --PowerCap set--
# Invalid BSIZE_X and BSIZE_Y combination: 6, 5
# 100%|██████████| 4/4 [00:00<00:00, 2673.23it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# 0it [00:00, ?it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# 0it [00:00, ?it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom
# 0it [00:00, ?it/s]
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: divide by zero encountered in scalar divide
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar multiply
#   l_j *= nom / denom
# /HackathonSEAVEA/.venv/lib/python3.12/site-packages/easyvvuq/analysis/sc_analysis.py:1400: RuntimeWarning: invalid value encountered in scalar divide
#   l_j *= nom / denom

# %% [markdown]
# This command retrieves the result after all refinements:

# %%
results = campaign.get_last_analysis()

# %%
# Out:
# {(0,): array([nan]), (1,): array([nan]), (2,): array([nan])}

# %% [markdown]
# The `adaptation_table` shows a plot of that visualizes which inputs got refined at what iteration. Note that the first / second order refinements (1 / 2 purple squares in a column) correspond to the $x_i$ / $x_ix_j$ terms of the loeppky function.

# %%
# %matplotlib inline
# with plt.xkcd():
analysis.adaptation_table()
plt.savefig('adaptation_table.png')

# %% [markdown]
# Since we are dealing with a polynomial test function, the (polynomial) SC approximation should be exact after sufficient iterations. In this case this happens after 10 iterations, and iteration 11 shown above does not improve the surrogate model further. This case be seen by examining the hierarchical surplus error values that were used to accept the multi indices into $\Lambda$. Note that the last two errors are essentially zero:

# %%
print(analysis.get_adaptation_errors())
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
analysis.get_pce_sobol_indices(QOI)
# Out:
# (array([nan]),
#  array([nan]),
#  {(0,): array([nan]), (1,): array([nan]), (2,): array([nan])},
#  {(0,): array([nan]), (1,): array([nan]), (2,): array([nan])})

# %%
def get_confidence_intervals(samples, conf=0.9):
    """
    Compute the confidence intervals given an array of samples

    Parameters
    ----------
    samples : array
        Samples on which to compute the intervals.
    conf : float, optional, must be in [0, 1].
        The confidence interval percentage. The default is 0.9.

    Returns
    -------
    lower : array
        The lower confidence bound..
    upper : array
        The upper confidence bound.

    """

    # ake sure conf is in [0, 1]
    if conf < 0.0 or conf > 1.0:
        print('conf must be specified within [0, 1]')
        return

    # lower bound = alpha, upper bound = 1 - alpha
    alpha = 0.5 * (1.0 - conf)

    # arrays for lower and upper bound of the interval
    n_samples = samples.shape[0]
    N_qoi = samples.shape[1]
    lower = np.zeros(N_qoi)
    upper = np.zeros(N_qoi)

    # the probabilities of the ecdf
    prob = np.linspace(0, 1, n_samples)
    # the closest locations in prob that correspond to the interval bounds
    idx0 = np.where(prob <= alpha)[0][-1]
    idx1 = np.where(prob <= 1.0 - alpha)[0][-1]

    # for every location of qoi compute the ecdf-based confidence interval
    for i in range(N_qoi):
        # the sorted surrogate samples at the current location
        samples_sorted = np.sort(samples[:, i])
        # the corresponding confidence interval
        lower[i] = samples_sorted[idx0]
        upper[i] = samples_sorted[idx1]

    return lower, upper

# %%
fig = plt.figure(figsize=[8,4])
ax = fig.add_subplot(121, xscale='log', xlabel='model evaluations', ylabel='mean')
ax.plot(np.cumsum(sampler.n_new_points), analysis.mean_history, '*', color='salmon', zorder=3, label='SC')
plt.legend(frameon=False)
ax = fig.add_subplot(122, xscale='log', xlabel='model evaluations', ylabel='standard deviation')
ax.plot(np.cumsum(sampler.n_new_points), np.array(analysis.std_history)**0.5, '*', color='salmon', zorder=3)
plt.tight_layout()

# %%
mean_SC = results.describe(QOI, 'mean')
std_SC = results.describe(QOI, 'std')


with plt.xkcd():
    fig = plt.figure(figsize=[8,4])
    ax = fig.add_subplot(121, xscale='log', xlabel='model evaluations', ylabel='mean')
    ax.plot(np.cumsum(sampler.n_new_points), analysis.mean_history, '*', color='salmon', zorder=3, label='SC')
    plt.legend(frameon=False)

    ax = fig.add_subplot(122, xscale='log', xlabel='model evaluations', ylabel='standard deviation')
    ax.plot(np.cumsum(sampler.n_new_points), np.array(analysis.std_history)**0.5, '*', color='salmon', zorder=3)
    plt.tight_layout()

# %% [markdown]
# Finally, we will create a plot with all first-order Sobol indices `S_i`, which shows the fraction of the output variance, that each input variable is responsible for *by itself*. To also estimate higher-order effects (the fraction of variance obtained by simultaneously varying 2 or more inputs together), we sum all first-order indices (shown in the first bar). Where this sum is close to one, there are (almost) no higher-order effects.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, title=r'First-order Sobol indices', ylim=[0,1])
ax.set_ylabel(r'$S_i$', fontsize=14)
sobols_first = np.array(list(results.sobols_first(QOI).values()))
ax.bar(0, np.sum(sobols_first), color='salmon')
ax.bar(np.arange(1, d+1), sobols_first.flatten(), color='dodgerblue')
labels = ['Total first order']
for i in range(d): labels.append('x%d' % (i+1))
ax.set_xticks(np.arange(d+1))
ax.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'Total first order'),
#  Text(1, 0, 'x1'),
#  Text(2, 0, 'x2'),
#  Text(3, 0, 'x3')]

# %%
results.describe(QOI, 'mean')
# Out:
# array([nan])
