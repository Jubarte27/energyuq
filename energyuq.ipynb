# %%
import energyuq

import programs
import machines

# %%
campaign, analysis = energyuq.create(programs.NONE, machines.Glados)
# Out:
# /home/mmachado/HPC/energyuq/.venv/lib/python3.9/site-packages/cerberus/validator.py:618: UserWarning: These types are defined both with a method and in the'types_mapping' property of this validator: {'integer'}
#   warn(
# Running NONE on Glados with N_THREADS = 8 and CLK = 1
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 299.55it/s]

# %%
energyuq.refine_and_analyse(campaign, analysis, 21)
# Out:
# -------1 iteration: 4 new points------
# Running NONE on Glados with N_THREADS = 8 and CLK = 2
# Running NONE on Glados with N_THREADS = 12 and CLK = 1
# Running NONE on Glados with N_THREADS = 5 and CLK = 1
# Running NONE on Glados with N_THREADS = 8 and CLK = 0
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 727.64it/s]
# -------2 iteration: 0 new points------
# 0it [00:00, ?it/s]
# -------3 iteration: 0 new points------
# 0it [00:00, ?it/s]
# -------4 iteration: 6 new points------
# Running NONE on Glados with N_THREADS = 3 and CLK = 1
# Running NONE on Glados with N_THREADS = 14 and CLK = 1
# Running NONE on Glados with N_THREADS = 12 and CLK = 0
# Running NONE on Glados with N_THREADS = 5 and CLK = 0
# Running NONE on Glados with N_THREADS = 12 and CLK = 2
# Running NONE on Glados with N_THREADS = 5 and CLK = 2
# ...

# %%
energyuq.save(campaign, analysis)
