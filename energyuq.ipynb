# %%
import energyuq

import programs
import machines

# %%
campaign, analysis = energyuq.create(programs.NONE, machines.Glados)
# Out:
# /home/mmachado/HPC/energyuq/.venv/lib/python3.9/site-packages/cerberus/validator.py:618: UserWarning: These types are defined both with a method and in the'types_mapping' property of this validator: {'integer'}
#   warn(
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 326.38it/s]

# %%
energyuq.refine_and_analyse(campaign, analysis, 21)
# Out:
# -----------------------1------------------------
# -----------------------4 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 747.28it/s]
# -----------------------2------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------3------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------4------------------------
# -----------------------6 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 1802.58it/s]
# -----------------------5------------------------
# -----------------------2 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 691.84it/s]
# -----------------------6------------------------
# -----------------------2 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 646.77it/s]
# -----------------------7------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------8------------------------
# -----------------------5 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1040.46it/s]
# -----------------------9------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------10------------------------
# -----------------------4 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 766.19it/s]
# -----------------------11------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------12------------------------
# -----------------------4 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1414.72it/s]
# -----------------------13------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------14------------------------
# -----------------------4 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1555.90it/s]
# -----------------------15------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------16------------------------
# -----------------------10 new points------------------------
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# /home/mmachado/HPC/energyuq
# Running NONE on Glados
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 2145.42it/s]
# -----------------------17------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------18------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------19------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]
# -----------------------20------------------------
# -----------------------0 new points------------------------
# 0it [00:00, ?it/s]

# %%
energyuq.save(campaign, analysis)
