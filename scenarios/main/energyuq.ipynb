# %%
from src import energyuq

from src import programs
from src import machines

import os
# Out:
# /home/mmachado/HPC/uq_sbac/.venv/lib/python3.14/site-packages/chaospy/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
campaign, analysis = energyuq.create(programs.FFT, machines.Glados)
# Out:
# /home/mmachado/HPC/uq_sbac/.venv/lib/python3.14/site-packages/cerberus/validator.py:618: UserWarning: These types are defined both with a method and in the'types_mapping' property of this validator: {'integer'}
#   warn(
# /home/mmachado/HPC/uq_sbac/.venv/lib/python3.14/site-packages/cerberus/validator.py:618: UserWarning: These types are defined both with a method and in the'types_mapping' property of this validator: {'integer'}
#   warn(
# Running FFT on Glados with N_THREADS = 8 and CLK = 1
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 599.53it/s]

# %%
energyuq.refine_and_analyse(campaign, analysis, 10)
# Out:
# -------1 iteration: 4 new points------
# Running FFT on Glados with N_THREADS = 8 and CLK = 2
# Running FFT on Glados with N_THREADS = 12 and CLK = 1
# Running FFT on Glados with N_THREADS = 4 and CLK = 1
# Running FFT on Glados with N_THREADS = 8 and CLK = 0
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 990.10it/s]
# -------2 iteration: 0 new points------
# 0it [00:00, ?it/s]
# -------3 iteration: 6 new points------
# Running FFT on Glados with N_THREADS = 4 and CLK = 0
# Running FFT on Glados with N_THREADS = 13 and CLK = 1
# Running FFT on Glados with N_THREADS = 3 and CLK = 1
# Running FFT on Glados with N_THREADS = 12 and CLK = 0
# Running FFT on Glados with N_THREADS = 4 and CLK = 2
# Running FFT on Glados with N_THREADS = 12 and CLK = 2
# ...

# %%
energyuq.save(campaign, analysis)
